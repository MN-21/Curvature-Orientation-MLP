# %% [markdown]
# <a href="https://colab.research.google.com/github/MN-21/handwriting-dnn-features/blob/main/Sobel_gradient_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install --quiet tensorflow tensorflow-datasets opencv-python scikit-learn tqdm

import cv2
import time
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# 1. Contour-gradient-free Sobel feature extractor (full-image gradients)
def compute_gradients(images):
    """
    Given a NumPy array of shape (N,28,28), returns
    an array of shape (N, 2, 28, 28) containing normalized gx, gy.
    """
    N = images.shape[0]
    grads = np.zeros((N, 2, 28, 28), dtype=np.float32)
    for i, img in enumerate(tqdm(images, desc="Computing gradients")):
        gx = cv2.Sobel(img, cv2.CV_32F, 1, 0, ksize=3)
        gy = cv2.Sobel(img, cv2.CV_32F, 0, 1, ksize=3)
        # normalize each to [0,1]
        gx = (gx - gx.min()) / (gx.max() - gx.min() + 1e-8)
        gy = (gy - gy.min()) / (gy.max() - gy.min() + 1e-8)
        grads[i,0] = gx
        grads[i,1] = gy
    return grads

# 2. Load EMNIST Letters via TFDS
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/letters',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# 3. Convert to NumPy arrays
all_images = []
all_labels = []
for img, lbl in tfds.as_numpy(ds_train.concatenate(ds_test)):
    all_images.append(img.squeeze())        # shape (28,28)
    all_labels.append(int(lbl) - 1)         # shift labels 1–26 → 0–25
all_images = np.stack(all_images)           # (145600,28,28)
all_labels = np.array(all_labels, dtype=int)

# 4. Stratified 80/20 train/test split
X_train, X_test, y_train, y_test = train_test_split(
    all_images, all_labels,
    train_size=0.8,
    stratify=all_labels,
    random_state=42
)

# 5. Compute Sobel gradient features
grad_train = compute_gradients(X_train)
grad_test  = compute_gradients(X_test)

# 6. Flatten to feature vectors (2*28*28 = 1568 dims)
X_train_feat = grad_train.reshape(-1, 2*28*28)
X_test_feat  = grad_test.reshape(-1, 2*28*28)

# 7. Build MLP model
model = models.Sequential([
    layers.Input(shape=(2*28*28,)),
    layers.Dense(1024), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(512), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(256), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.3),

    layers.Dense(26, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 8. Callbacks
es = callbacks.EarlyStopping(
    monitor='val_accuracy', patience=4,
    restore_best_weights=True, verbose=1
)
rlr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5,
    patience=3, min_lr=1e-6, verbose=1
)

# 9. Train
t0 = time.time()
history = model.fit(
    X_train_feat, y_train,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[es, rlr],
    verbose=2
)
train_time = time.time() - t0

# 10. Evaluate
t1 = time.time()
test_loss, test_acc = model.evaluate(X_test_feat, y_test, verbose=2)
infer_time = time.time() - t1

# 11. Report
print(f"\nEMNIST Letters Sobel-Gradient MLP")
print(f"Test Accuracy   : {test_acc*100:.2f}%")
print(f"Training Time   : {train_time:.1f}s")
print(f"Inference Time  : {infer_time:.1f}s for {X_test_feat.shape[0]} samples")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/emnist/letters/3.1.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/emnist/letters/3.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/emnist/letters/incomplete.WJNAEJ_3.1.0/emnist-train.tfrecord*...:   0%|   …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/emnist/letters/incomplete.WJNAEJ_3.1.0/emnist-test.tfrecord*...:   0%|    …
# Dataset emnist downloaded and prepared to /root/tensorflow_datasets/emnist/letters/3.1.0. Subsequent calls will reuse this data.
# Computing gradients: 100%|██████████| 82880/82880 [00:05<00:00, 14397.77it/s]
# Computing gradients: 100%|██████████| 20720/20720 [00:01<00:00, 18578.10it/s]
# Epoch 1/50
# 583/583 - 37s - 63ms/step - accuracy: 0.6413 - loss: 1.1979 - val_accuracy: 0.5731 - val_loss: 1.3557 - learning_rate: 1.0000e-03
# Epoch 2/50
# 583/583 - 40s - 69ms/step - accuracy: 0.7848 - loss: 0.6836 - val_accuracy: 0.4595 - val_loss: 2.2807 - learning_rate: 1.0000e-03
# Epoch 3/50
# 583/583 - 41s - 70ms/step - accuracy: 0.8198 - loss: 0.5582 - val_accuracy: 0.6295 - val_loss: 1.2068 - learning_rate: 1.0000e-03
# Epoch 4/50
# 583/583 - 35s - 59ms/step - accuracy: 0.8418 - loss: 0.4898 - val_accuracy: 0.8048 - val_loss: 0.6105 - learning_rate: 1.0000e-03
# Epoch 5/50
# 583/583 - 40s - 68ms/step - accuracy: 0.8544 - loss: 0.4446 - val_accuracy: 0.6108 - val_loss: 1.4527 - learning_rate: 1.0000e-03
# Epoch 6/50
# 583/583 - 33s - 56ms/step - accuracy: 0.8650 - loss: 0.4110 - val_accuracy: 0.7115 - val_loss: 0.9641 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 583/583 - 41s - 70ms/step - accuracy: 0.8740 - loss: 0.3850 - val_accuracy: 0.8003 - val_loss: 0.6299 - learning_rate: 1.0000e-03
# Epoch 8/50
# 583/583 - 43s - 74ms/step - accuracy: 0.8874 - loss: 0.3371 - val_accuracy: 0.8690 - val_loss: 0.4065 - learning_rate: 5.0000e-04
# Epoch 9/50
# 583/583 - 41s - 71ms/step - accuracy: 0.8942 - loss: 0.3137 - val_accuracy: 0.8779 - val_loss: 0.3788 - learning_rate: 5.0000e-04
# Epoch 10/50
# 583/583 - 32s - 55ms/step - accuracy: 0.8985 - loss: 0.3006 - val_accuracy: 0.8976 - val_loss: 0.2978 - learning_rate: 5.0000e-04
# Epoch 11/50
# 583/583 - 34s - 58ms/step - accuracy: 0.9017 - loss: 0.2902 - val_accuracy: 0.8850 - val_loss: 0.3602 - learning_rate: 5.0000e-04
# Epoch 12/50
# 583/583 - 41s - 70ms/step - accuracy: 0.9026 - loss: 0.2824 - val_accuracy: 0.8819 - val_loss: 0.3547 - learning_rate: 5.0000e-04
# Epoch 13/50
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 583/583 - 34s - 58ms/step - accuracy: 0.9059 - loss: 0.2744 - val_accuracy: 0.8949 - val_loss: 0.3138 - learning_rate: 5.0000e-04
# Epoch 14/50
# 583/583 - 42s - 72ms/step - accuracy: 0.9121 - loss: 0.2538 - val_accuracy: 0.9118 - val_loss: 0.2679 - learning_rate: 2.5000e-04
# Epoch 15/50
# 583/583 - 40s - 68ms/step - accuracy: 0.9156 - loss: 0.2416 - val_accuracy: 0.9147 - val_loss: 0.2564 - learning_rate: 2.5000e-04
# Epoch 16/50
# 583/583 - 32s - 56ms/step - accuracy: 0.9183 - loss: 0.2333 - val_accuracy: 0.9134 - val_loss: 0.2523 - learning_rate: 2.5000e-04
# Epoch 17/50
# 583/583 - 43s - 73ms/step - accuracy: 0.9200 - loss: 0.2288 - val_accuracy: 0.9146 - val_loss: 0.2560 - learning_rate: 2.5000e-04
# Epoch 18/50
# 583/583 - 32s - 56ms/step - accuracy: 0.9217 - loss: 0.2229 - val_accuracy: 0.9140 - val_loss: 0.2733 - learning_rate: 2.5000e-04
# Epoch 19/50
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 583/583 - 34s - 59ms/step - accuracy: 0.9215 - loss: 0.2217 - val_accuracy: 0.9172 - val_loss: 0.2575 - learning_rate: 2.5000e-04
# Epoch 20/50
# 583/583 - 40s - 69ms/step - accuracy: 0.9256 - loss: 0.2098 - val_accuracy: 0.9217 - val_loss: 0.2403 - learning_rate: 1.2500e-04
# Epoch 21/50
# 583/583 - 41s - 71ms/step - accuracy: 0.9265 - loss: 0.2066 - val_accuracy: 0.9223 - val_loss: 0.2300 - learning_rate: 1.2500e-04
# Epoch 22/50
# 583/583 - 36s - 62ms/step - accuracy: 0.9272 - loss: 0.2048 - val_accuracy: 0.9239 - val_loss: 0.2304 - learning_rate: 1.2500e-04
# Epoch 23/50
# 583/583 - 33s - 57ms/step - accuracy: 0.9291 - loss: 0.2011 - val_accuracy: 0.9183 - val_loss: 0.2420 - learning_rate: 1.2500e-04
# Epoch 24/50
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 583/583 - 43s - 73ms/step - accuracy: 0.9287 - loss: 0.1977 - val_accuracy: 0.9218 - val_loss: 0.2390 - learning_rate: 1.2500e-04
# Epoch 25/50
# 583/583 - 40s - 69ms/step - accuracy: 0.9305 - loss: 0.1931 - val_accuracy: 0.9235 - val_loss: 0.2320 - learning_rate: 6.2500e-05
# Epoch 26/50
# 583/583 - 33s - 56ms/step - accuracy: 0.9322 - loss: 0.1906 - val_accuracy: 0.9250 - val_loss: 0.2290 - learning_rate: 6.2500e-05
# Epoch 27/50
# 583/583 - 41s - 70ms/step - accuracy: 0.9316 - loss: 0.1901 - val_accuracy: 0.9239 - val_loss: 0.2304 - learning_rate: 6.2500e-05
# Epoch 28/50
# 583/583 - 43s - 74ms/step - accuracy: 0.9314 - loss: 0.1872 - val_accuracy: 0.9248 - val_loss: 0.2332 - learning_rate: 6.2500e-05
# Epoch 29/50
# 583/583 - 32s - 56ms/step - accuracy: 0.9325 - loss: 0.1866 - val_accuracy: 0.9234 - val_loss: 0.2280 - learning_rate: 6.2500e-05
# Epoch 30/50
# 583/583 - 34s - 58ms/step - accuracy: 0.9333 - loss: 0.1847 - val_accuracy: 0.9245 - val_loss: 0.2308 - learning_rate: 6.2500e-05
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 648/648 - 5s - 7ms/step - accuracy: 0.9235 - loss: 0.2355
#
# EMNIST Letters Sobel-Gradient MLP
# Test Accuracy   : 92.35%
# Training Time   : 1130.8s
# Inference Time  : 5.0s for 20720 samples

# %%
# Install dependencies
# !pip install --quiet tensorflow tensorflow-datasets opencv-python tqdm scikit-learn

import cv2
import time
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# 1. Sobel feature extractor (full-image gradients)
def compute_gradients(images):
    """
    Given a NumPy array of shape (N,28,28), returns
    an array of shape (N, 2, 28, 28) containing normalized gx, gy.
    """
    N = images.shape[0]
    grads = np.zeros((N, 2, 28, 28), dtype=np.float32)
    for i, img in enumerate(tqdm(images, desc="Computing gradients")):
        gx = cv2.Sobel(img, cv2.CV_32F, 1, 0, ksize=3)
        gy = cv2.Sobel(img, cv2.CV_32F, 0, 1, ksize=3)
        # normalize each to [0,1]
        gx = (gx - gx.min()) / (gx.max() - gx.min() + 1e-8)
        gy = (gy - gy.min()) / (gy.max() - gy.min() + 1e-8)
        grads[i,0] = gx
        grads[i,1] = gy
    return grads

# 2. Load MNIST via TFDS
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# 3. Convert to NumPy arrays
all_images = []
all_labels = []
for img, lbl in tfds.as_numpy(ds_train.concatenate(ds_test)):
    all_images.append(img.squeeze())  # shape (28,28)
    all_labels.append(int(lbl))       # labels 0–9
all_images = np.stack(all_images)    # (70000,28,28)
all_labels = np.array(all_labels, dtype=int)

# 4. Stratified 80/20 train/test split
X_train, X_test, y_train, y_test = train_test_split(
    all_images, all_labels,
    train_size=0.8,
    stratify=all_labels,
    random_state=42
)

# 5. Compute Sobel gradient features
grad_train = compute_gradients(X_train)
grad_test  = compute_gradients(X_test)

# 6. Flatten to feature vectors (2*28*28 = 1568 dims)
X_train_feat = grad_train.reshape(-1, 2*28*28)
X_test_feat  = grad_test.reshape(-1, 2*28*28)

# 7. Build MLP model for 10 classes
model = models.Sequential([
    layers.Input(shape=(2*28*28,)),
    layers.Dense(1024), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(512), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(256), layers.BatchNormalization(), layers.Activation('relu'),
    layers.Dropout(0.3),

    layers.Dense(10, activation='softmax')  # 10 output classes for MNIST digits
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 8. Callbacks
es = callbacks.EarlyStopping(
    monitor='val_accuracy', patience=4,
    restore_best_weights=True, verbose=1
)
rlr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5,
    patience=3, min_lr=1e-6, verbose=1
)

# 9. Train
t0 = time.time()
history = model.fit(
    X_train_feat, y_train,
    validation_split=0.1,
    epochs=50,
    batch_size=128,
    callbacks=[es, rlr],
    verbose=2
)
train_time = time.time() - t0

# 10. Evaluate
t1 = time.time()
test_loss, test_acc = model.evaluate(X_test_feat, y_test, verbose=2)
infer_time = time.time() - t1

# 11. Report
print(f"\nMNIST Sobel-Gradient MLP")
print(f"Test Accuracy   : {test_acc*100:.2f}%")
print(f"Training Time   : {train_time:.1f}s")
print(f"Inference Time  : {infer_time:.1f}s for {X_test_feat.shape[0]} samples")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.KAQYD6_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.KAQYD6_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# Computing gradients: 100%|██████████| 56000/56000 [00:03<00:00, 15232.79it/s]
# Computing gradients: 100%|██████████| 14000/14000 [00:00<00:00, 15394.57it/s]
# Epoch 1/50
# 394/394 - 26s - 66ms/step - accuracy: 0.8878 - loss: 0.3636 - val_accuracy: 0.3880 - val_loss: 3.3054 - learning_rate: 1.0000e-03
# Epoch 2/50
# 394/394 - 25s - 63ms/step - accuracy: 0.9466 - loss: 0.1740 - val_accuracy: 0.5698 - val_loss: 2.7193 - learning_rate: 1.0000e-03
# Epoch 3/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9582 - loss: 0.1331 - val_accuracy: 0.5411 - val_loss: 2.1740 - learning_rate: 1.0000e-03
# Epoch 4/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9638 - loss: 0.1146 - val_accuracy: 0.5962 - val_loss: 1.8342 - learning_rate: 1.0000e-03
# Epoch 5/50
# 394/394 - 23s - 58ms/step - accuracy: 0.9688 - loss: 0.0976 - val_accuracy: 0.4148 - val_loss: 3.0778 - learning_rate: 1.0000e-03
# Epoch 6/50
# 394/394 - 24s - 60ms/step - accuracy: 0.9716 - loss: 0.0892 - val_accuracy: 0.5359 - val_loss: 2.2001 - learning_rate: 1.0000e-03
# Epoch 7/50
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 394/394 - 43s - 108ms/step - accuracy: 0.9748 - loss: 0.0757 - val_accuracy: 0.3355 - val_loss: 4.9598 - learning_rate: 1.0000e-03
# Epoch 8/50
# 394/394 - 39s - 98ms/step - accuracy: 0.9817 - loss: 0.0565 - val_accuracy: 0.9005 - val_loss: 0.3343 - learning_rate: 5.0000e-04
# Epoch 9/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9834 - loss: 0.0504 - val_accuracy: 0.7804 - val_loss: 1.1953 - learning_rate: 5.0000e-04
# Epoch 10/50
# 394/394 - 23s - 59ms/step - accuracy: 0.9847 - loss: 0.0464 - val_accuracy: 0.9223 - val_loss: 0.2409 - learning_rate: 5.0000e-04
# Epoch 11/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9857 - loss: 0.0435 - val_accuracy: 0.7395 - val_loss: 0.9912 - learning_rate: 5.0000e-04
# Epoch 12/50
# 394/394 - 43s - 109ms/step - accuracy: 0.9859 - loss: 0.0421 - val_accuracy: 0.8439 - val_loss: 0.5241 - learning_rate: 5.0000e-04
# Epoch 13/50
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 394/394 - 40s - 103ms/step - accuracy: 0.9870 - loss: 0.0391 - val_accuracy: 0.8291 - val_loss: 0.6164 - learning_rate: 5.0000e-04
# Epoch 14/50
# 394/394 - 23s - 58ms/step - accuracy: 0.9885 - loss: 0.0352 - val_accuracy: 0.9659 - val_loss: 0.1272 - learning_rate: 2.5000e-04
# Epoch 15/50
# 394/394 - 42s - 106ms/step - accuracy: 0.9909 - loss: 0.0271 - val_accuracy: 0.9688 - val_loss: 0.1116 - learning_rate: 2.5000e-04
# Epoch 16/50
# 394/394 - 40s - 101ms/step - accuracy: 0.9908 - loss: 0.0273 - val_accuracy: 0.9745 - val_loss: 0.1001 - learning_rate: 2.5000e-04
# Epoch 17/50
# 394/394 - 42s - 107ms/step - accuracy: 0.9913 - loss: 0.0264 - val_accuracy: 0.9604 - val_loss: 0.1423 - learning_rate: 2.5000e-04
# Epoch 18/50
# 394/394 - 40s - 102ms/step - accuracy: 0.9920 - loss: 0.0243 - val_accuracy: 0.9682 - val_loss: 0.1111 - learning_rate: 2.5000e-04
# Epoch 19/50
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 394/394 - 40s - 102ms/step - accuracy: 0.9930 - loss: 0.0217 - val_accuracy: 0.9621 - val_loss: 0.1579 - learning_rate: 2.5000e-04
# Epoch 20/50
# 394/394 - 42s - 105ms/step - accuracy: 0.9932 - loss: 0.0206 - val_accuracy: 0.9786 - val_loss: 0.0850 - learning_rate: 1.2500e-04
# Epoch 21/50
# 394/394 - 43s - 108ms/step - accuracy: 0.9943 - loss: 0.0176 - val_accuracy: 0.9816 - val_loss: 0.0802 - learning_rate: 1.2500e-04
# Epoch 22/50
# 394/394 - 24s - 60ms/step - accuracy: 0.9936 - loss: 0.0182 - val_accuracy: 0.9768 - val_loss: 0.0955 - learning_rate: 1.2500e-04
# Epoch 23/50
# 394/394 - 23s - 58ms/step - accuracy: 0.9941 - loss: 0.0181 - val_accuracy: 0.9795 - val_loss: 0.0827 - learning_rate: 1.2500e-04
# Epoch 24/50
# 394/394 - 22s - 56ms/step - accuracy: 0.9942 - loss: 0.0175 - val_accuracy: 0.9811 - val_loss: 0.0796 - learning_rate: 1.2500e-04
# Epoch 25/50
# 394/394 - 42s - 107ms/step - accuracy: 0.9945 - loss: 0.0167 - val_accuracy: 0.9802 - val_loss: 0.0764 - learning_rate: 1.2500e-04
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 438/438 - 3s - 7ms/step - accuracy: 0.9802 - loss: 0.0806
#
# MNIST Sobel-Gradient MLP
# Test Accuracy   : 98.02%
# Training Time   : 867.2s
# Inference Time  : 3.3s for 14000 samples
